# %% [markdown]
# <a href="https://colab.research.google.com/github/MarinaSaran6/br-python-challenges/blob/master/Raspagem_tentativa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

# %%
url= 'https://especiais.gazetadopovo.com.br/eleicoes/2018/resultados/mapa-eleitoral-de-presidente-por-municipios/'

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
conteudo = requests.get(url).content

# %%
conteudo
# Out:
# b'<!DOCTYPE html>\n<html lang="pt-BR" prefix="og: http://ogp.me/ns#">\n    <head>\n        <meta charset="utf-8">\n        <meta name="viewport" content="width=device-width, initial-scale=1.0">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n        <meta name="google-site-verification" content="5b6LVOfWyI-2tXbcuEQa32Q4p8_IIdfwMl0_UKBg3oc" />\n\n                    <link rel="amphtml" href="https://especiais.gazetadopovo.com.br/eleicoes/2018/resultados/mapa-eleitoral-de-presidente-por-municipios?amp=true" />\n\t\t\n        <title>Mapa eleitoral: Presidente | Munic\xc3\xadpios | Resultados Elei\xc3\xa7\xc3\xb5es 2018</title>\n\n        \n        <meta name="cXenseParse:gdp-especiais" content="eleicoes">\n\t\t<meta name="cXenseParse:publishtime" content="2018-10-28T17:00:00Z"/>\n\t\t<meta name="cXenseParse:recs:recommendable" content="false"/>\n\t\t<meta property="article:modified_time" content="2019-07-31T10:00:00Z"/>\n\n                <script type="text/javascript">\
# ...

# %%
from bs4 import BeautifulSoup

# %%
sopa = BeautifulSoup(conteudo)

# %%
sopa
# Out:
# <!DOCTYPE html>
# <html lang="pt-BR" prefix="og: http://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="5b6LVOfWyI-2tXbcuEQa32Q4p8_IIdfwMl0_UKBg3oc" name="google-site-verification"/>
# <link href="https://especiais.gazetadopovo.com.br/eleicoes/2018/resultados/mapa-eleitoral-de-presidente-por-municipios?amp=true" rel="amphtml"/>
# <title>Mapa eleitoral: Presidente | Municípios | Resultados Eleições 2018</title>
# <meta content="eleicoes" name="cXenseParse:gdp-especiais"/>
# <meta content="2018-10-28T17:00:00Z" name="cXenseParse:publishtime"/>
# <meta content="false" name="cXenseParse:recs:recommendable"/>
# <meta content="2019-07-31T10:00:00Z" property="article:modified_time"/>
# <script type="text/javascript">
#         	var idBlocoAnuncio = '\/7601\/gp-especiais\/eleicoes\/2018\/resultados\/mapa-eleitoral-de-presidente-por-municipios';
# ...

# %%
sopa.find('td', class_='votos-validos')
# Out:
# <td class="votos-validos">5.029</td>

# %%
vv = sopa.find_all('td', class_='votos-validos')

# %%
vv
# Out:
# [<td class="votos-validos">5.029</td>,
#  <td class="votos-validos">1.919</td>,
#  <td class="votos-validos">5.503</td>,
#  <td class="votos-validos">4.807</td>,
#  <td class="votos-validos">3.476</td>,
#  <td class="votos-validos">2.678</td>,
#  <td class="votos-validos">3.688</td>,
#  <td class="votos-validos">2.411</td>,
#  <td class="votos-validos">3.380</td>,
#  <td class="votos-validos">16.308</td>,
#  <td class="votos-validos">2.987</td>,
#  <td class="votos-validos">4.786</td>,
#  <td class="votos-validos">2.766</td>,
#  <td class="votos-validos">7.432</td>,
#  <td class="votos-validos">6.220</td>,
#  <td class="votos-validos">5.232</td>,
#  <td class="votos-validos">13.508</td>,
#  <td class="votos-validos">12.259</td>,
#  <td class="votos-validos">10.567</td>,
#  <td class="votos-validos">2.609</td>]

# %%
lista_vv = []

# %%
for padrao in vv:
  vb = re.findall('<td class="votos-validos">(.*)</td>', str(padrao))
  lista_vv.append(vv[0])

# %%
lista_vv
# Out:
# [<td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>,
#  <td class="votos-validos">5.029</td>]

# %%
sopa.find('td', class_='-dos-votos-em-bolsonaro')
# Out:
# <td class="-dos-votos-em-bolsonaro">83,89%</td>

# %%
vb = sopa.find_all('td', class_='-dos-votos-em-bolsonaro')

# %%
vb
# Out:
# [<td class="-dos-votos-em-bolsonaro">83,89%</td>,
#  <td class="-dos-votos-em-bolsonaro">82,75%</td>,
#  <td class="-dos-votos-em-bolsonaro">81,46%</td>,
#  <td class="-dos-votos-em-bolsonaro">81,32%</td>,
#  <td class="-dos-votos-em-bolsonaro">80,93%</td>,
#  <td class="-dos-votos-em-bolsonaro">80,77%</td>,
#  <td class="-dos-votos-em-bolsonaro">80,26%</td>,
#  <td class="-dos-votos-em-bolsonaro">80,26%</td>,
#  <td class="-dos-votos-em-bolsonaro">79,85%</td>,
#  <td class="-dos-votos-em-bolsonaro">79,68%</td>]

# %%
lista_vb = []

# %%
for padrao in vb:
  vb = re.findall('<td class="-dos-votos-em-bolsonaro">(.*)</td>', str(padrao))
  lista_vb.append(vb[0])

# %%
lista_vb
# Out:
# ['83,89%',
#  '82,75%',
#  '81,46%',
#  '81,32%',
#  '80,93%',
#  '80,77%',
#  '80,26%',
#  '80,26%',
#  '79,85%',
#  '79,68%']

# %%
len(lista_vv)
# Out:
# 20

# %%
len(lista_vb)
# Out:
# 10

# %%
votos = {'vv': lista_vv, 
'vb': lista_vb,}

# %%
import pandas as pd

# %%
df = pd.DataFrame

# %%
df_pagina1 = pd.DataFrame(columns=['vv','vb'])

df_pagina1['vv'] = lista_vv
df_pagina1['vb'] = ista_vb
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-3eb21a13d482> in <module>()
#       2
#       3 df_pagina1['vv'] = lista_vv
# ----> 4 df_pagina1['vb'] = ista_vb
#
# NameError: name 'ista_vb' is not defined

# %%
df_pagina1
# Out:
#          vv   vb
# 0   [5.029]  NaN
# 1   [5.029]  NaN
# 2   [5.029]  NaN
# 3   [5.029]  NaN
# 4   [5.029]  NaN
# 5   [5.029]  NaN
# 6   [5.029]  NaN
# 7   [5.029]  NaN
# 8   [5.029]  NaN
# 9   [5.029]  NaN
# 10  [5.029]  NaN
# 11  [5.029]  NaN
# 12  [5.029]  NaN
# 13  [5.029]  NaN
# 14  [5.029]  NaN
# 15  [5.029]  NaN
# 16  [5.029]  NaN
# 17  [5.029]  NaN
# 18  [5.029]  NaN
# 19  [5.029]  NaN
